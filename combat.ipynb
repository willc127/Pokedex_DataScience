# %%
import pandas as pd

# %%
#importing the data
data = pd.read_csv('Pokemon.csv')
df = pd.DataFrame(data)
df2 = df.iloc[:,1:19]
df2
# Out:
#      against_bug  against_dark  against_dragon  against_electric  \
# 0           1.00           1.0             1.0               0.5
# 1           1.00           1.0             1.0               0.5
# 2           1.00           1.0             1.0               0.5
# 3           0.50           1.0             1.0               1.0
# 4           0.50           1.0             1.0               1.0
# ..           ...           ...             ...               ...
# 796         0.25           1.0             0.5               2.0
# 797         1.00           1.0             0.5               0.5
# 798         2.00           0.5             2.0               0.5
# 799         2.00           2.0             1.0               1.0
# 800         0.25           0.5             0.0               1.0
#
#      against_fairy  against_fight  against_fire  against_flying  \
# 0              0.5            0.5           2.0             2.0
# ...

# %%
combatDF = df2.T
combatDF.columns = df['name']
combatDF
# Out:
# name              Bulbasaur  Ivysaur  Venusaur  Charmander  Charmeleon  \
# against_bug            1.00     1.00      1.00         0.5         0.5
# against_dark           1.00     1.00      1.00         1.0         1.0
# against_dragon         1.00     1.00      1.00         1.0         1.0
# against_electric       0.50     0.50      0.50         1.0         1.0
# against_fairy          0.50     0.50      0.50         0.5         0.5
# against_fight          0.50     0.50      0.50         1.0         1.0
# against_fire           2.00     2.00      2.00         0.5         0.5
# against_flying         2.00     2.00      2.00         1.0         1.0
# against_ghost          1.00     1.00      1.00         1.0         1.0
# against_grass          0.25     0.25      0.25         0.5         0.5
# against_ground         1.00     1.00      1.00         2.0         2.0
# against_ice            2.00     2.00      2.00         0.5         0.5
# ...

# %%
#save combatDF to csv file 
combatDF.to_csv('against_categories.csv', index=True)
